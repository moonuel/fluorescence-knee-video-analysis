# %%
import utils.io as io 

io.concatenate_avi("aging_knee_radial_seg_(old_method).avi", "aging_knee_radial_seg_(new_method).avi", "aging_knee_radial_seg_(old_vs_new_comparison).avi")
io.concatenate_avi("aging_knee_radial_seg_LMR_(old_method).avi", "aging_knee_radial_seg_LMR_(new_method).avi", "aging_knee_radial_seg_LMR_(old_vs_new_comparison).avi")
# Out:
# Saved to: c:\Users\olimoon\Documents\Development\Applied Math MSc 2024-2026\knee segmentation\scripts\aging_knee_radial_seg_(old_vs_new_comparison).avi
# Saved to: c:\Users\olimoon\Documents\Development\Applied Math MSc 2024-2026\knee segmentation\scripts\aging_knee_radial_seg_LMR_(old_vs_new_comparison).avi

# %%
import utils.io as io

io.convert_avi_to_mp4("../docs/meetings/aging radial segmentation old vs new comparison/aging_knee_radial_seg_(old_vs_new_comparison).avi")
io.convert_avi_to_mp4("../docs/meetings/aging radial segmentation old vs new comparison/aging_knee_radial_seg_LMR_(old_vs_new_comparison).avi")
# Out:
# Saved MP4 to ../docs/meetings/aging radial segmentation old vs new comparison/aging_knee_radial_seg_(old_vs_new_comparison).mp4
# Saved MP4 to ../docs/meetings/aging radial segmentation old vs new comparison/aging_knee_radial_seg_LMR_(old_vs_new_comparison).mp4

# %%
import utils.io as io 

io.concatenate_avi("aging_knee_radial_seg_(old_method).avi", "aging_knee_radial_seg_(old_method, N=64).avi", "aging_knee_radial_seg_(old_method, 16_vs_64_comparison).avi")
io.concatenate_avi("aging_knee_radial_seg_LMR_(old_method).avi", "aging_knee_radial_seg_LMR_(old_method, N=64).avi", "aging_knee_radial_seg_LMR_(old_method, 16_vs_64_comparison).avi")
# Out:
# Saved to: c:\Users\olimoon\Documents\Development\Applied Math MSc 2024-2026\knee segmentation\scripts\aging_knee_radial_seg_(old_method, 16_vs_64_comparison).avi
# Saved to: c:\Users\olimoon\Documents\Development\Applied Math MSc 2024-2026\knee segmentation\scripts\aging_knee_radial_seg_LMR_(old_method, 16_vs_64_comparison).avi

# %%
import utils.io as io

io.convert_avi_to_mp4("aging_knee_radial_seg_(old_method, 16_vs_64_comparison).avi")
io.convert_avi_to_mp4("aging_knee_radial_seg_LMR_(old_method, 16_vs_64_comparison).avi")
# Out:
# Saved MP4 to aging_knee_radial_seg_(old_method, 16_vs_64_comparison).mp4
# Saved MP4 to aging_knee_radial_seg_LMR_(old_method, 16_vs_64_comparison).mp4
